# %% [markdown]
# # 01. Importing libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
#Define path
path = r'C:\Users\astat\Documents\Instacart Basket Analysis'

# %%
#Import data
df_orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_altered.pkl'))

# %% [markdown]
# # 03. Grouping

# %%
#Grouping data
df_orders_products_merged.groupby('product_name')

# %% [markdown]
# # 04. Aggregating

# %%
#aggregating average orders per department
df_orders_products_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# Compared to the subset all department IDs are listed now and the average numbers of orders per department range from 15.21 to 22.9.

# %% [markdown]
# # 05. Loyalty Flag

# %%
#Aggregating orders for customers
df_orders_products_merged['max_order'] = df_orders_products_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
pd.options.display.max_rows = None

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered  ...  product_name aisle_id  department_id  prices  _merge  \
# 0          0  ...          Soda       77              7     9.0    both
# 1          1  ...          Soda       77              7     9.0    both
# 2          1  ...          Soda       77              7     9.0    both
# 3          1  ...          Soda       77              7     9.0    both
# 4          1  ...          Soda       77              7     9.0    both
#
#          price_range     busiest_day     busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy   Regularly busy        Average orders
# 1  Mid-range product  Regularly busy  Least busy days        Average orders
# 2  Mid-range product  Regularly busy  Least busy days           Most orders
# 3  Mid-range product      Least busy  Least busy days        Average orders
# 4  Mid-range product      Least busy  Least busy days           Most orders
#
#   max_order
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#
# [5 rows x 21 columns]

# %%
#Adding loyalty flags
df_orders_products_merged.loc[df_orders_products_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['max_order'] <= 40) & (df_orders_products_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_orders_products_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# # 06. Price average for customers

# %%
#aggregating average prices per customer group
df_orders_products_merged.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                     prices
#                       mean
# loyalty_flag
# Loyal customer    7.773575
# New customer      7.801206
# Regular customer  7.798262

# %% [markdown]
# New customers buy higher priced items on average, whereas loyal customers on average tend to buy lower price products.

# %% [markdown]
# # 07. Spending Flag

# %%
#Aggregating spending for customers
df_orders_products_merged['mean_spending'] = df_orders_products_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered  ...  department_id prices  _merge        price_range  \
# 0          0  ...              7    9.0    both  Mid-range product
# 1          1  ...              7    9.0    both  Mid-range product
# 2          1  ...              7    9.0    both  Mid-range product
# 3          1  ...              7    9.0    both  Mid-range product
# 4          1  ...              7    9.0    both  Mid-range product
#
#       busiest_day     busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy   Regularly busy        Average orders        10
# 1  Regularly busy  Least busy days        Average orders        10
# 2  Regularly busy  Least busy days           Most orders        10
# 3      Least busy  Least busy days        Average orders        10
# 4      Least busy  Least busy days           Most orders        10
#
#    loyalty_flag mean_spending
# 0  New customer      6.367797
# 1  New customer      6.367797
# 2  New customer      6.367797
# 3  New customer      6.367797
# 4  New customer      6.367797
#
# [5 rows x 23 columns]

# %%
#Adding spending flags
df_orders_products_merged.loc[df_orders_products_merged['mean_spending'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_orders_products_merged.loc[df_orders_products_merged['mean_spending'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_orders_products_merged['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     32285131
# High spender      119728
# Name: spending_flag, dtype: int64

# %% [markdown]
# # 08. Frequency flag

# %%
#Aggregating spending for customers
df_orders_products_merged['order_frequency'] = df_orders_products_merged.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered  ...  _merge        price_range     busiest_day     busiest_days  \
# 0          0  ...    both  Mid-range product  Regularly busy   Regularly busy
# 1          1  ...    both  Mid-range product  Regularly busy  Least busy days
# 2          1  ...    both  Mid-range product  Regularly busy  Least busy days
# 3          1  ...    both  Mid-range product      Least busy  Least busy days
# 4          1  ...    both  Mid-range product      Least busy  Least busy days
#
#    busiest_period_of_day max_order  loyalty_flag mean_spending spending_flag  \
# 0         Average orders        10  New customer      6.367797   Low spender
# 1         Average orders        10  New customer      6.367797   Low spender
# 2            Most orders        10  New customer      6.367797   Low spender
# 3         Average orders        10  New customer      6.367797   Low spender
# 4            Most orders        10  New customer      6.367797   Low spender
#
#   order_frequency
# 0            20.5
# 1            20.5
# 2            20.5
# 3            20.5
# 4            20.5
#
# [5 rows x 25 columns]

# %%
#Adding frequency flags
df_orders_products_merged.loc[df_orders_products_merged['order_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['order_frequency'] <= 20) & (df_orders_products_merged['order_frequency'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
df_orders_products_merged.loc[df_orders_products_merged['order_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
df_orders_products_merged['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %% [markdown]
# # 09. Export data

# %%
# Export data to pkl
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_grouped.pkl'))

# %%
df_orders_products_merged.groupby('orders_day_of_week').agg({'prices': ['mean']})
# Out:
#                       prices
#                         mean
# orders_day_of_week
# 0                   7.857590
# 1                   7.759697
# 2                   7.754309
# 3                   7.757485
# 4                   7.756223
# 5                   7.762477
# 6                   7.857431
